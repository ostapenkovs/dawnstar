# %% [markdown]
# Libraries

# %%
import psycopg2
from psycopg2.extensions import AsIs

import glob
import pandas as pd
import io

import time

from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

import warnings
warnings.filterwarnings('ignore')

from config import db_info

# %% [markdown]
# DB Connection

# %%
schema_name = 'sc'

conn = psycopg2.connect(**db_info)
conn.autocommit = True

curs = conn.cursor()
curs.execute(f'set search_path to {schema_name}')

# %% [markdown]
# SureChembl Files

# %%
data_folder = './sure_chembl_data/'
files = glob.glob(data_folder + '*.txt.gz')

colnames = ['id', 'smiles', 'inchi_key', 'corpus_freq', 'patent_id', \
            'pub_date', 'field_type', 'field_freq']

compound = 'compound'
cmp_cols = ['id', 'smiles']

patent = 'patent'
pat_cols = ['patent_id', 'pub_date']

field_freq = 'field_freq'
fld_cols = ['id', 'patent_id', 'field_type', 'field_freq']

# %% [markdown]
# Populating DB

# %%
for f_idx, f in enumerate(files):
    ###
    # read one file
    df = pd.read_csv(f, header=None, sep='\t')
    df.columns = colnames

    # filter the file
    df = df.drop(['inchi_key', 'corpus_freq'], axis=1)
    df['id'] = df.id.apply(lambda x: x.split('SCHEMBL')[1]).astype(int)
    df['patent_id'] = df.patent_id.apply(lambda x: ''.join(x.split('-')))
    df = df[df.patent_id.str[0:2] == 'US']
    ###

    ###
    container = dict()
    for tbl, cols in zip([compound, patent, field_freq], [cmp_cols, pat_cols, fld_cols]):
        container[tbl] = df[cols].drop_duplicates(cols[:-1])
    df = None
    ###

    ###
    # upserting compounds
    start = time.time()
    invalid_compounds = []
    i_idx = 0
    for id, smi in zip(container[compound].id, container[compound].smiles):
        if i_idx % 50000 == 0 and i_idx > 0:
            print(f'Processed {i_idx} compounds out of {len(container[compound])}.')
        
        m = Chem.MolFromSmiles(smi)
        if not m: 
            invalid_compounds.append(id)
            continue
        can_smi = Chem.MolToSmiles(m, canonical=True)
        if not can_smi: 
            invalid_compounds.append(id)
            continue
        b_mfp = DataStructs.BitVectToBinaryText( AllChem.GetMorganFingerprintAsBitVect(m, 2, nBits=1024) )

        try:
            curs.execute('insert into %(tbl)s values (%(id)s, %(smi)s::mol, bfp_from_binary_text(%(mfp)s)) \
                on conflict (id) do update set smiles = excluded.smiles, mfp = excluded.mfp',
                {'tbl': AsIs(compound), 'id': id, 'smi': can_smi, 'mfp': b_mfp})
            
        except Exception as e:
            print(e)
            invalid_compounds.append(id)
        
        m = can_smi = b_mfp = None
        i_idx += 1
    
    del container[compound]

    if len(invalid_compounds) >= 1:
        container[field_freq] = container[field_freq][ ~(container[field_freq].id.isin(invalid_compounds)) ]
        container[patent] = container[patent][ (container[patent].patent_id.isin( container[field_freq].patent_id.unique().tolist() )) ]
    invalid_compounds = None
    
    print(f'Compounds took {time.time() - start} seconds.')
    ###
    
    ###
    # upserting patents
    start = time.time()
    curs.execute(f'create table tmp_{patent} (like {patent} including defaults)')

    buf = io.StringIO(container[patent].to_csv(index=False, header=True, sep=','))
    del container[patent]
    curs.copy_expert(sql=f"copy tmp_{patent} (num, pub_date) from stdin with csv header delimiter as ','", file=buf)
    buf = None

    curs.execute(f'insert into {patent} select * from tmp_{patent} on conflict (num) \
                 do update set pub_date = excluded.pub_date returning num, id')
    
    # need the patent map!
    patent_map = {k: v for k, v in curs.fetchall()}

    curs.execute(f'drop table tmp_{patent}')
    container[field_freq]['patent_id'] = container[field_freq].patent_id.map(patent_map)
    patent_map = None

    print(f'Patents took {time.time() - start} seconds.')
    ###

    ###
    # upserting field frequencies
    start = time.time()

    curs.execute(f'create table tmp_{field_freq} (like {field_freq} including defaults)')

    buf = io.StringIO(container[field_freq].to_csv(index=False, header=True, sep=','))
    del container[field_freq]
    curs.copy_expert(sql=f"copy tmp_{field_freq} from stdin with csv header delimiter as ','", file=buf)
    buf = None

    curs.execute(f'insert into {field_freq} select * from tmp_{field_freq} on conflict (compound_id, patent_id, field_id) \
                 do update set freq = excluded.freq')
    curs.execute(f'drop table tmp_{field_freq}')

    print(f'Field freqs took {time.time() - start} seconds.')
    ###

    print(f'Processed file number {f_idx + 1} out of {len(files)}.')
# Out:
# Processed 50000 compounds out of 664622.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# could not create molecule from SMILES 'CC1(C)CCCC(C)(C)[N-]1.[Li]Cl.[Mg+2]Cl'
# LINE 1: insert into compound values (9894115, 'CC1(C)CCCC(C)(C)[N-]1...
#                                               ^
#
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# Processed 100000 compounds out of 664622.
# could not create molecule from SMILES 'CCCC[O-].CC[Mg+2]'
# LINE 1: insert into compound values (1988209, 'CCCC[O-].CC[Mg+2]'::m...
#                                               ^
#
# could not create molecule from SMILES 'CC(C)C[O-].CCC[Mg+2]'
# LINE 1: insert into compound values (1988608, 'CC(C)C[O-].CCC[Mg+2]'...
#                                               ^
#
# Processed 150000 compounds out of 664622.
# could not create molecule from SMILES 'CCCC[O-].CCC[Mg+2]'
# LINE 1: insert into compound values (1989001, 'CCCC[O-].CCC[Mg+2]'::...
#                                               ^
#
# Processed 200000 compounds out of 664622.
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# could not create molecule from SMILES 'Br.C=CCCC[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (899944, 'Br.C=CCCC[O-].[Mg+2]c1...
#                                              ^
#
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# Processed 250000 compounds out of 664622.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# Processed 300000 compounds out of 664622.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# could not create molecule from SMILES 'Br.COc1cccc([Mg+2])c1.[O-]Cc1ccccc1'
# LINE 1: insert into compound values (2447392, 'Br.COc1cccc([Mg+2])c1...
#                                               ^
#
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 350000 compounds out of 664622.
# could not create molecule from SMILES 'CC(C)C[Mg+2].CCCC[O-]'
# LINE 1: insert into compound values (1996119, 'CC(C)C[Mg+2].CCCC[O-]...
#                                               ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# Processed 400000 compounds out of 664622.
# could not create molecule from SMILES 'CC(C)C[Mg+2].CC(C)C[O-]'
# LINE 1: insert into compound values (1988514, 'CC(C)C[Mg+2].CC(C)C[O...
#                                               ^
#
# Processed 450000 compounds out of 664622.
# could not create molecule from SMILES 'Br.COc1ccccc1[Mg+2].C[O-]'
# LINE 1: insert into compound values (4025198, 'Br.COc1ccccc1[Mg+2].C...
#                                               ^
#
# Processed 500000 compounds out of 664622.
# could not create molecule from SMILES 'CC(C)C[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (1992818, 'CC(C)C[O-].CCCC[Mg+2]...
#                                               ^
#
# could not create molecule from SMILES 'CCCCCC[O-].CC[Mg+2]'
# LINE 1: insert into compound values (1987922, 'CCCCCC[O-].CC[Mg+2]':...
#                                               ^
#
# could not create molecule from SMILES 'CC(C)C[O-].CC[Mg+2]'
# LINE 1: insert into compound values (1990465, 'CC(C)C[O-].CC[Mg+2]':...
#                                               ^
#
# Processed 550000 compounds out of 664622.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# could not create molecule from SMILES 'CC(C)C[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1989230, 'CC(C)C[Mg+2].CC[O-]':...
#                                               ^
#
# could not create molecule from SMILES 'CCCCCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (713798, 'CCCCCCCC[O-].[Mg+2]Cl'...
#                                              ^
#
# Processed 600000 compounds out of 664622.
# could not create molecule from SMILES 'CCCC[Mg+2].CCCC[O-]'
# LINE 1: insert into compound values (1990040, 'CCCC[Mg+2].CCCC[O-]':...
#                                               ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# Processed 650000 compounds out of 664622.
# Compounds took 806.3005609512329 seconds.
# Patents took 0.44499993324279785 seconds.
# Field freqs took 46.465757608413696 seconds.
# Processed file number 1 out of 32.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# Processed 50000 compounds out of 684192.
# Processed 100000 compounds out of 684192.
# Processed 150000 compounds out of 684192.
# Processed 200000 compounds out of 684192.
# Processed 250000 compounds out of 684192.
# Processed 300000 compounds out of 684192.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 350000 compounds out of 684192.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 400000 compounds out of 684192.
# Processed 450000 compounds out of 684192.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# could not create molecule from SMILES 'O=C1CCCCC=N1.[Mg+2]Br'
# LINE 1: insert into compound values (9441872, 'O=C1CCCCC=N1.[Mg+2]Br...
#                                               ^
#
# Processed 500000 compounds out of 684192.
# Processed 550000 compounds out of 684192.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# Processed 600000 compounds out of 684192.
# could not create molecule from SMILES 'Br.C=CCCC[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (899944, 'Br.C=CCCC[O-].[Mg+2]c1...
#                                              ^
#
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# Processed 650000 compounds out of 684192.
# Compounds took 772.3813076019287 seconds.
# Patents took 0.5568184852600098 seconds.
# Field freqs took 53.12693190574646 seconds.
# Processed file number 2 out of 32.
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# Processed 50000 compounds out of 748733.
# could not create molecule from SMILES 'CC1(C)CCCC(C)(C)[N-]1.[Li]Cl.[Mg+2]Cl'
# LINE 1: insert into compound values (9894115, 'CC1(C)CCCC(C)(C)[N-]1...
#                                               ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# Processed 100000 compounds out of 748733.
# could not create molecule from SMILES 'Br.C[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (971124, 'Br.C[O-].[Mg+2]c1ccccc...
#                                              ^
#
# Processed 150000 compounds out of 748733.
# Processed 200000 compounds out of 748733.
# Processed 250000 compounds out of 748733.
# Processed 300000 compounds out of 748733.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# Processed 350000 compounds out of 748733.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 400000 compounds out of 748733.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 450000 compounds out of 748733.
# could not create molecule from SMILES 'O=COC1C=c2cc3cc4cc5cc6cc7ccc(C(=O)O)c8c9c%10c%11c%12c%13c%14c%15c%16c%17c%18c%19c(c%20c%21c%22c(cc(C(=O)O)c%23cc%24cc%25c(C(=O)O)c%26cc%27cc%28c%29c%30c%31c%32c%33c(c%34c%35c%36c%37c%38c%39c%40c%41c(c2=C2C1=CC(=CC%36=CC%34OC=O)C%37C2%40)c3c1c4c2c5c(c6c%11c78)c%12c3c%14c4c5c%15c6c7c%16c%19c%21c8c(c%23%22)c%24c%11c%25c%12c%26c%14c%27c%29c%15c%31c%16c%33c%35c%38c%19c%21c%39c%22c%41c1c(c23)c4c%22c1c%21c2c(c%16%19)c%15c%14c3c%12c(c%11c78)c6c(c51)c32)=CC(OC=O)C%32=CC%30CC=%28C(=O)O)C(C(=O)O)C=%20)=CCC=%18C(=C%10C%17%13)CC9'
# LINE 1: insert into compound values (14330474, 'O=COC1C=c2cc3cc4cc5c...
#                                                ^
#
# Processed 500000 compounds out of 748733.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# Processed 550000 compounds out of 748733.
# Processed 600000 compounds out of 748733.
# Processed 650000 compounds out of 748733.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# could not create molecule from SMILES 'O=C(O)C1=c2cc3cc4c(C(=O)O)c5cc6cc7c(C(=O)O)cc8c9c%10c(c%11c%12c%13c%14c%15c%16c%17c%18c%19c%20c%21c(c%22c(C(=O)O)ccc%23cc%24cc%25cc%26cc%27cc%28c%29c%30c%31c%32c%33c%34c%35c%36c%37c(c%38c%39c%40c%41c(c2c2c3c3c4c4c5c5c6c(c79)c6c%10c%12c%15c7c9c%16c%10c%12c%17c%15c%19c(c%24c%20c%23%22)c%25c%16c%26c(c%27%30)c%17c%31c%19c%33c%20c%22c%34c%37c%39c%23c%41c2c2c3c3c4c(c5c76)c9c4c%10c(c%19c%12c%17c%16%15)c%20c(c2c%23%22)c34)C(C=C%40C(C(=O)O)C=%38)C1)C(C(=O)O)C=C%36C=C1C=C(C=%29C%32C1%35)C(C(=O)O)C=%28)CCC(=C%21C%14%18)C=%13CC=%11)=CC8C(=O)O'
# LINE 1: insert into compound values (14331494, 'O=C(O)C1=c2cc3cc4c(C...
#                                                ^
#
# Processed 700000 compounds out of 748733.
# Compounds took 878.6941025257111 seconds.
# Patents took 0.5306079387664795 seconds.
# Field freqs took 54.683653354644775 seconds.
# Processed file number 3 out of 32.
# could not create molecule from SMILES 'CC1(C)CCCC(C)(C)[N-]1.[Li]Cl.[Mg+2]Cl'
# LINE 1: insert into compound values (9894115, 'CC1(C)CCCC(C)(C)[N-]1...
#                                               ^
#
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# Processed 50000 compounds out of 805944.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# Processed 100000 compounds out of 805944.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# Processed 150000 compounds out of 805944.
# Processed 200000 compounds out of 805944.
# could not create molecule from SMILES 'CCCC[O-].CC[Mg+2]'
# LINE 1: insert into compound values (1988209, 'CCCC[O-].CC[Mg+2]'::m...
#                                               ^
#
# could not create molecule from SMILES 'Br.C[N-]C.[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (544888, 'Br.C[N-]C.[Mg+2]c1cccc...
#                                              ^
#
# Processed 250000 compounds out of 805944.
# could not create molecule from SMILES 'CCCCCCCC[Mg+2].CCCC[O-]'
# LINE 1: insert into compound values (2273170, 'CCCCCCCC[Mg+2].CCCC[O...
#                                               ^
#
# Processed 300000 compounds out of 805944.
# Processed 350000 compounds out of 805944.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# Processed 400000 compounds out of 805944.
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 450000 compounds out of 805944.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 500000 compounds out of 805944.
# Processed 550000 compounds out of 805944.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# could not create molecule from SMILES 'C[Mg+2].[O-]c1ccccc1'
# LINE 1: insert into compound values (6057679, 'C[Mg+2].[O-]c1ccccc1'...
#                                               ^
#
# Processed 600000 compounds out of 805944.
# Processed 650000 compounds out of 805944.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# Processed 700000 compounds out of 805944.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (713798, 'CCCCCCCC[O-].[Mg+2]Cl'...
#                                              ^
#
# could not create molecule from SMILES 'Clc1c(Cl)c2c3cc4c5c(Cl)c(Cl)c(Cl)c6c7c(Cl)c(Cl)c(Cl)c8c9c(Cl)c(Cl)c%10c%11c(Cl)c(Cl)c%12c%13c(Cl)c(Cl)c(Cl)c%14c%15c(Cl)c(Cl)c(Cl)c%16c%17cc%18c%19c(Cl)c(Cl)c(Cl)c%20c%21c(Cl)c(Cl)c(Cl)c%22c%23c(Cl)c(Cl)c%24c%25c(Cl)c(Cl)c%26c%27c(Cl)c(Cl)c(Cl)c%28c(c1Cl)c2c1c(c%28%27)c2c%26c%25c%25c%26c%24c%23c%23c(c%21%22)c(c%19%20)c%19c%18c%18c%17c%17c(c%16%15)c(c%14%13)c%13c%12c%11c%11c%12c%10c9c9c(c78)c(c56)c5c4c4c3c1c1c2c%25c2c3c%26c%23c%19c6c%18c7c%17c%13c%11c8c%10c%12c9c5c5c4c1c2c(c5%10)c(c63)c78'
# LINE 1: insert into compound values (15832810, 'Clc1c(Cl)c2c3cc4c5c(...
#                                                ^
#
# Processed 750000 compounds out of 805944.
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# Processed 800000 compounds out of 805944.
# Compounds took 948.6241161823273 seconds.
# Patents took 0.6739583015441895 seconds.
# Field freqs took 62.13475275039673 seconds.
# Processed file number 4 out of 32.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# Processed 50000 compounds out of 710244.
# Processed 100000 compounds out of 710244.
# Processed 150000 compounds out of 710244.
# Processed 200000 compounds out of 710244.
# Processed 250000 compounds out of 710244.
# Processed 300000 compounds out of 710244.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# Processed 350000 compounds out of 710244.
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 400000 compounds out of 710244.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 450000 compounds out of 710244.
# Processed 500000 compounds out of 710244.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# Processed 550000 compounds out of 710244.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# Processed 600000 compounds out of 710244.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# Processed 650000 compounds out of 710244.
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# Processed 700000 compounds out of 710244.
# Compounds took 815.3299984931946 seconds.
# Patents took 0.5457193851470947 seconds.
# Field freqs took 52.70179200172424 seconds.
# Processed file number 5 out of 32.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# could not create molecule from SMILES 'CC1(C)CCCC(C)(C)[N-]1.[Li]Cl.[Mg+2]Cl'
# LINE 1: insert into compound values (9894115, 'CC1(C)CCCC(C)(C)[N-]1...
#                                               ^
#
# Processed 50000 compounds out of 723820.
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# Processed 100000 compounds out of 723820.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# Processed 150000 compounds out of 723820.
# could not create molecule from SMILES 'CC(C)C[O-].CCC[Mg+2]'
# LINE 1: insert into compound values (1988608, 'CC(C)C[O-].CCC[Mg+2]'...
#                                               ^
#
# could not create molecule from SMILES 'CC(C)(C)[Ca]1(C(C)(C)C)CCNC1=O'
# LINE 1: insert into compound values (2603713, 'CC(C)(C)[Ca]1(C(C)(C)...
#                                               ^
#
# could not create molecule from SMILES 'CCCC[O-].CC[Mg+2]'
# LINE 1: insert into compound values (1988209, 'CCCC[O-].CC[Mg+2]'::m...
#                                               ^
#
# Processed 200000 compounds out of 723820.
# Processed 250000 compounds out of 723820.
# could not create molecule from SMILES 'CC(C)C[Mg+2].CCCC[O-]'
# LINE 1: insert into compound values (1996119, 'CC(C)C[Mg+2].CCCC[O-]...
#                                               ^
#
# Processed 300000 compounds out of 723820.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# could not create molecule from SMILES 'CC(C)C[O-].CC[Mg+2]'
# LINE 1: insert into compound values (1990465, 'CC(C)C[O-].CC[Mg+2]':...
#                                               ^
#
# Processed 350000 compounds out of 723820.
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 400000 compounds out of 723820.
# could not create molecule from SMILES 'CCCC[O-].CCC[Mg+2]'
# LINE 1: insert into compound values (1989001, 'CCCC[O-].CCC[Mg+2]'::...
#                                               ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 450000 compounds out of 723820.
# Processed 500000 compounds out of 723820.
# could not create molecule from SMILES 'CC(C)C[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1989230, 'CC(C)C[Mg+2].CC[O-]':...
#                                               ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC[O-].CC[Mg+2]'
# LINE 1: insert into compound values (1987922, 'CCCCCC[O-].CC[Mg+2]':...
#                                               ^
#
# could not create molecule from SMILES 'CCCC[Mg+2].CCCC[O-]'
# LINE 1: insert into compound values (1990040, 'CCCC[Mg+2].CCCC[O-]':...
#                                               ^
#
# Processed 550000 compounds out of 723820.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# Processed 600000 compounds out of 723820.
# could not create molecule from SMILES 'CC(C)C[Mg+2].CC(C)C[O-]'
# LINE 1: insert into compound values (1988514, 'CC(C)C[Mg+2].CC(C)C[O...
#                                               ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# Processed 650000 compounds out of 723820.
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (713798, 'CCCCCCCC[O-].[Mg+2]Cl'...
#                                              ^
#
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# could not create molecule from SMILES 'CC(C)C[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (1992818, 'CC(C)C[O-].CCCC[Mg+2]...
#                                               ^
#
# Processed 700000 compounds out of 723820.
# Compounds took 845.1672196388245 seconds.
# Patents took 0.5250000953674316 seconds.
# Field freqs took 52.25968384742737 seconds.
# Processed file number 6 out of 32.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# Processed 50000 compounds out of 697410.
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# Processed 100000 compounds out of 697410.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# Processed 150000 compounds out of 697410.
# Processed 200000 compounds out of 697410.
# Processed 250000 compounds out of 697410.
# Processed 300000 compounds out of 697410.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# Processed 350000 compounds out of 697410.
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 400000 compounds out of 697410.
# could not create molecule from SMILES 'CCC[Mg+2].C[N-]C.Cl'
# LINE 1: insert into compound values (907685, 'CCC[Mg+2].C[N-]C.Cl'::...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCN1C[N-]CN(CCCCC)C1.[Mg+2]Cl'
# LINE 1: insert into compound values (1961861, 'CCCCCN1C[N-]CN(CCCCC)...
#                                               ^
#
# Processed 450000 compounds out of 697410.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# Processed 500000 compounds out of 697410.
# Processed 500000 compounds out of 697410.
# Processed 550000 compounds out of 697410.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# Processed 600000 compounds out of 697410.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# Processed 650000 compounds out of 697410.
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# Compounds took 783.5592348575592 seconds.
# Patents took 0.5089945793151855 seconds.
# Field freqs took 51.35442042350769 seconds.
# Processed file number 7 out of 32.
# Processed 50000 compounds out of 761918.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# Processed 100000 compounds out of 761918.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# Processed 150000 compounds out of 761918.
# Processed 200000 compounds out of 761918.
# Processed 250000 compounds out of 761918.
# Processed 300000 compounds out of 761918.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# Processed 350000 compounds out of 761918.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 400000 compounds out of 761918.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 450000 compounds out of 761918.
# Processed 500000 compounds out of 761918.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# Processed 550000 compounds out of 761918.
# Processed 600000 compounds out of 761918.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# Processed 650000 compounds out of 761918.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# Processed 700000 compounds out of 761918.
# Processed 750000 compounds out of 761918.
# Compounds took 859.0397658348083 seconds.
# Patents took 0.5600075721740723 seconds.
# Field freqs took 55.48680567741394 seconds.
# Processed file number 8 out of 32.
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# Processed 50000 compounds out of 773600.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# Processed 100000 compounds out of 773600.
# Processed 150000 compounds out of 773600.
# could not create molecule from SMILES 'CCCC[O-].CC[Mg+2]'
# LINE 1: insert into compound values (1988209, 'CCCC[O-].CC[Mg+2]'::m...
#                                               ^
#
# Processed 200000 compounds out of 773600.
# Processed 250000 compounds out of 773600.
# could not create molecule from SMILES 'CCCCCCCC[Mg+2].CCCC[O-]'
# LINE 1: insert into compound values (2273170, 'CCCCCCCC[Mg+2].CCCC[O...
#                                               ^
#
# Processed 300000 compounds out of 773600.
# Processed 350000 compounds out of 773600.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 400000 compounds out of 773600.
# Processed 450000 compounds out of 773600.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 500000 compounds out of 773600.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# Processed 550000 compounds out of 773600.
# Processed 600000 compounds out of 773600.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# Processed 650000 compounds out of 773600.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (713798, 'CCCCCCCC[O-].[Mg+2]Cl'...
#                                              ^
#
# Processed 700000 compounds out of 773600.
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# Processed 750000 compounds out of 773600.
# Compounds took 877.4600307941437 seconds.
# Patents took 0.5299849510192871 seconds.
# Field freqs took 56.46774411201477 seconds.
# Processed file number 9 out of 32.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# Processed 50000 compounds out of 822939.
# Processed 100000 compounds out of 822939.
# could not create molecule from SMILES 'CC1(C)CCCC(C)(C)[N-]1.[Li]Cl.[Mg+2]Cl'
# LINE 1: insert into compound values (9894115, 'CC1(C)CCCC(C)(C)[N-]1...
#                                               ^
#
# Processed 150000 compounds out of 822939.
# Processed 200000 compounds out of 822939.
# Processed 250000 compounds out of 822939.
# Processed 300000 compounds out of 822939.
# could not create molecule from SMILES 'C[O-].Cl.[Mg+2]c1ccncc1'
# LINE 1: insert into compound values (677686, 'C[O-].Cl.[Mg+2]c1ccncc...
#                                              ^
#
# Processed 350000 compounds out of 822939.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# Processed 400000 compounds out of 822939.
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 450000 compounds out of 822939.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 500000 compounds out of 822939.
# Processed 550000 compounds out of 822939.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# Processed 600000 compounds out of 822939.
# Processed 650000 compounds out of 822939.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# Processed 700000 compounds out of 822939.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# could not create molecule from SMILES 'Br.C[O-].Cc1cccc([Mg+2])c1'
# LINE 1: insert into compound values (1021780, 'Br.C[O-].Cc1cccc([Mg+...
#                                               ^
#
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# Processed 750000 compounds out of 822939.
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# Processed 800000 compounds out of 822939.
# Compounds took 935.071417093277 seconds.
# Patents took 0.5620241165161133 seconds.
# Field freqs took 61.23986554145813 seconds.
# Processed file number 10 out of 32.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# Processed 50000 compounds out of 858455.
# Processed 100000 compounds out of 858455.
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# could not create molecule from SMILES 'Br.C[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (971124, 'Br.C[O-].[Mg+2]c1ccccc...
#                                              ^
#
# Processed 150000 compounds out of 858455.
# Processed 200000 compounds out of 858455.
# Processed 250000 compounds out of 858455.
# Processed 300000 compounds out of 858455.
# could not create molecule from SMILES 'C[O-].Cl.[Mg+2]c1ccncc1'
# LINE 1: insert into compound values (677686, 'C[O-].Cl.[Mg+2]c1ccncc...
#                                              ^
#
# Processed 350000 compounds out of 858455.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# Processed 400000 compounds out of 858455.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 450000 compounds out of 858455.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 500000 compounds out of 858455.
# Processed 550000 compounds out of 858455.
# Processed 600000 compounds out of 858455.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# Processed 650000 compounds out of 858455.
# Processed 700000 compounds out of 858455.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# Processed 750000 compounds out of 858455.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# could not create molecule from SMILES 'Br.C[O-].Cc1cccc([Mg+2])c1'
# LINE 1: insert into compound values (1021780, 'Br.C[O-].Cc1cccc([Mg+...
#                                               ^
#
# Processed 800000 compounds out of 858455.
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# Processed 850000 compounds out of 858455.
# Compounds took 990.6942338943481 seconds.
# Patents took 0.528998851776123 seconds.
# Field freqs took 61.93006873130798 seconds.
# Processed file number 11 out of 32.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# Processed 50000 compounds out of 833352.
# Processed 100000 compounds out of 833352.
# Processed 150000 compounds out of 833352.
# Processed 200000 compounds out of 833352.
# Processed 250000 compounds out of 833352.
# Processed 300000 compounds out of 833352.
# Processed 350000 compounds out of 833352.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# Processed 400000 compounds out of 833352.
# Processed 450000 compounds out of 833352.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 500000 compounds out of 833352.
# Processed 550000 compounds out of 833352.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# Processed 600000 compounds out of 833352.
# Processed 650000 compounds out of 833352.
# Processed 700000 compounds out of 833352.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# Processed 750000 compounds out of 833352.
# Processed 800000 compounds out of 833352.
# Compounds took 1001.5121579170227 seconds.
# Patents took 0.5599985122680664 seconds.
# Field freqs took 59.93721580505371 seconds.
# Processed file number 12 out of 32.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# Processed 50000 compounds out of 701401.
# Processed 100000 compounds out of 701401.
# could not create molecule from SMILES 'CC1(C)CCCC(C)(C)[N-]1.[Li]Cl.[Mg+2]Cl'
# LINE 1: insert into compound values (9894115, 'CC1(C)CCCC(C)(C)[N-]1...
#                                               ^
#
# Processed 150000 compounds out of 701401.
# Processed 200000 compounds out of 701401.
# Processed 250000 compounds out of 701401.
# Processed 300000 compounds out of 701401.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# Processed 350000 compounds out of 701401.
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 400000 compounds out of 701401.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 450000 compounds out of 701401.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# Processed 500000 compounds out of 701401.
# Processed 550000 compounds out of 701401.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# Processed 600000 compounds out of 701401.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# could not create molecule from SMILES 'Br.C[O-].Cc1cccc([Mg+2])c1'
# LINE 1: insert into compound values (1021780, 'Br.C[O-].Cc1cccc([Mg+...
#                                               ^
#
# Processed 650000 compounds out of 701401.
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# Compounds took 840.2649731636047 seconds.
# Patents took 0.5379979610443115 seconds.
# Field freqs took 52.49734354019165 seconds.
# Processed file number 13 out of 32.
# Processed 50000 compounds out of 765518.
# Processed 100000 compounds out of 765518.
# Processed 150000 compounds out of 765518.
# Processed 200000 compounds out of 765518.
# Processed 250000 compounds out of 765518.
# Processed 300000 compounds out of 765518.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# ...
# Processed 300000 compounds out of 766084.
# Processed 350000 compounds out of 766084.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# Processed 400000 compounds out of 766084.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 450000 compounds out of 766084.
# Processed 500000 compounds out of 766084.
# could not create molecule from SMILES 'CCOC(=O)C([Mg+2])C(=O)OCC.CC[O-]'
# LINE 1: insert into compound values (4254384, 'CCOC(=O)C([Mg+2])C(=O...
#                                               ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# Processed 550000 compounds out of 766084.
# Processed 600000 compounds out of 766084.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# Processed 650000 compounds out of 766084.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# could not create molecule from SMILES 'Br.C[O-].Cc1cccc([Mg+2])c1'
# LINE 1: insert into compound values (1021780, 'Br.C[O-].Cc1cccc([Mg+...
#                                               ^
#
# Processed 700000 compounds out of 766084.
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# Processed 750000 compounds out of 766084.
# Compounds took 959.0842924118042 seconds.
# Patents took 0.5915641784667969 seconds.
# Field freqs took 57.10532474517822 seconds.
# Processed file number 26 out of 32.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 50000 compounds out of 613672.
# could not create molecule from SMILES 'CC1(C)CCCC(C)(C)[N-]1.[Li]Cl.[Mg+2]Cl'
# LINE 1: insert into compound values (9894115, 'CC1(C)CCCC(C)(C)[N-]1...
#                                               ^
#
# Processed 100000 compounds out of 613672.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# Processed 150000 compounds out of 613672.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# Processed 200000 compounds out of 613672.
# could not create molecule from SMILES 'CCCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (495331, 'CCCCCC[O-].[Mg+2]Cl'::...
#                                              ^
#
# Processed 250000 compounds out of 613672.
# Processed 300000 compounds out of 613672.
# could not create molecule from SMILES 'CCCCCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (713798, 'CCCCCCCC[O-].[Mg+2]Cl'...
#                                              ^
#
# Processed 350000 compounds out of 613672.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# Processed 400000 compounds out of 613672.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# Processed 450000 compounds out of 613672.
# Processed 500000 compounds out of 613672.
# Processed 550000 compounds out of 613672.
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# Processed 600000 compounds out of 613672.
# Compounds took 764.4618318080902 seconds.
# Patents took 0.47900867462158203 seconds.
# Field freqs took 46.068413972854614 seconds.
# Processed file number 27 out of 32.
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 50000 compounds out of 519963.
# Processed 100000 compounds out of 519963.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# Processed 150000 compounds out of 519963.
# Processed 200000 compounds out of 519963.
# Processed 250000 compounds out of 519963.
# could not create molecule from SMILES 'CCCCCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (713798, 'CCCCCCCC[O-].[Mg+2]Cl'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# Processed 300000 compounds out of 519963.
# Processed 350000 compounds out of 519963.
# Processed 400000 compounds out of 519963.
# Processed 450000 compounds out of 519963.
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# Processed 500000 compounds out of 519963.
# Compounds took 638.7479829788208 seconds.
# Patents took 0.5089914798736572 seconds.
# Field freqs took 46.50373554229736 seconds.
# Processed file number 28 out of 32.
# could not create molecule from SMILES 'Br.C[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (971124, 'Br.C[O-].[Mg+2]c1ccccc...
#                                              ^
#
# Processed 50000 compounds out of 383097.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# could not create molecule from SMILES 'CC(C)(C)[Ca]1(C(C)(C)C)CNC(=O)O1'
# LINE 1: insert into compound values (2603719, 'CC(C)(C)[Ca]1(C(C)(C)...
#                                               ^
#
# Processed 100000 compounds out of 383097.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# Processed 150000 compounds out of 383097.
# could not create molecule from SMILES 'Br.CC[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (3138354, 'Br.CC[O-].[Mg+2]c1ccc...
#                                               ^
#
# Processed 200000 compounds out of 383097.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# Processed 250000 compounds out of 383097.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# could not create molecule from SMILES 'C[O-].Cl.[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (972035, 'C[O-].Cl.[Mg+2]c1ccccc...
#                                              ^
#
# Processed 300000 compounds out of 383097.
# Processed 350000 compounds out of 383097.
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# Compounds took 465.5759422779083 seconds.
# Patents took 0.3619968891143799 seconds.
# Field freqs took 31.88097620010376 seconds.
# Processed file number 29 out of 32.
# Processed 50000 compounds out of 531599.
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# Processed 100000 compounds out of 531599.
# Processed 150000 compounds out of 531599.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# Processed 200000 compounds out of 531599.
# Processed 250000 compounds out of 531599.
# Processed 300000 compounds out of 531599.
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# Processed 350000 compounds out of 531599.
# could not create molecule from SMILES 'C[Mg+2].Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (714950, 'C[Mg+2].Cl.[O-]c1ccccc...
#                                              ^
#
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# Processed 400000 compounds out of 531599.
# could not create molecule from SMILES 'CCCCCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (713798, 'CCCCCCCC[O-].[Mg+2]Cl'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# Processed 450000 compounds out of 531599.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# Processed 500000 compounds out of 531599.
# could not create molecule from SMILES 'Cc1ccccc1[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (714951, 'Cc1ccccc1[O-].[Mg+2]Cl...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# Compounds took 674.2291867733002 seconds.
# Patents took 0.4629943370819092 seconds.
# Field freqs took 42.99992489814758 seconds.
# Processed file number 30 out of 32.
# Processed 50000 compounds out of 236223.
# Processed 100000 compounds out of 236223.
# could not create molecule from SMILES 'C[Mg+2].Cc1ccccc1[O-]'
# LINE 1: insert into compound values (716319, 'C[Mg+2].Cc1ccccc1[O-]'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCC[Mg+2]'
# LINE 1: insert into compound values (152865, 'CCCCCC(=O)[O-].CCCC[Mg...
#                                              ^
#
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CCCCCC[Mg+2]'
# LINE 1: insert into compound values (154273, 'CCCCCC(=O)[O-].CCCCCC[...
#                                              ^
#
# Processed 150000 compounds out of 236223.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].C[Mg+2]'
# LINE 1: insert into compound values (151105, 'CCCCCC(=O)[O-].C[Mg+2]...
#                                              ^
#
# could not create molecule from SMILES 'CCCCC[O-].[Mg+2]Cl'
# LINE 1: insert into compound values (440672, 'CCCCC[O-].[Mg+2]Cl'::m...
#                                              ^
#
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]Cc1ccccc1'
# LINE 1: insert into compound values (148431, 'CCCCCC(=O)[O-].[Mg+2]C...
#                                              ^
#
# could not create molecule from SMILES 'CCCCCC(=O)[O-].CC[Mg+2]'
# LINE 1: insert into compound values (153158, 'CCCCCC(=O)[O-].CC[Mg+2...
#                                              ^
#
# Processed 200000 compounds out of 236223.
# could not create molecule from SMILES 'CCCCCC(=O)[O-].[Mg+2]c1ccccc1'
# LINE 1: insert into compound values (149901, 'CCCCCC(=O)[O-].[Mg+2]c...
#                                              ^
#
# Compounds took 287.5863802433014 seconds.
# Patents took 0.23804545402526855 seconds.
# Field freqs took 17.221330165863037 seconds.
# Processed file number 31 out of 32.
# Processed 50000 compounds out of 303856.
# Processed 100000 compounds out of 303856.
# Processed 150000 compounds out of 303856.
# could not create molecule from SMILES 'CCCC[Mg+2].CC[O-]'
# LINE 1: insert into compound values (1563033, 'CCCC[Mg+2].CC[O-]'::m...
#                                               ^
#
# could not create molecule from SMILES '[Mg+2]Cl.[O-]c1ccccc1'
# LINE 1: insert into compound values (715306, '[Mg+2]Cl.[O-]c1ccccc1'...
#                                              ^
#
# Processed 200000 compounds out of 303856.
# Processed 250000 compounds out of 303856.
# Processed 300000 compounds out of 303856.
# Compounds took 388.1840476989746 seconds.
# Patents took 0.22299718856811523 seconds.
# Field freqs took 19.684564113616943 seconds.
# Processed file number 32 out of 32.

# %% [markdown]
# Creating Indices

# %%
curs.execute('create index smi_idx on compound using gist(smiles)')
curs.execute('create index mfp_idx on compound using gist(mfp)')

# %% [markdown]
# Testing Similarity and Substructure Searching

# %%
s = 'CC[C@]1(c2ccccc2)C(=O)NC(=O)N(C)C1=O'

curs.execute('select c.id, mol_to_smiles(c.smiles), p.num from compound c, patent p, field_freq f \
             where c.id = f.compound_id and p.id = f.patent_id \
             and c.smiles@>%s', (s, ))

r = curs.fetchall()

# %%
r[0]
# Out:
# (1255360,
#  'CCCCOCC(CN1C(=O)N(CC(COCCCC)OC(N)=O)C(=O)C(CC)(c2ccccc2)C1=O)OC(N)=O',
#  'US20150004244A1')

# %%
s = 'CC[C@]1(c2ccccc2)C(=O)NC(=O)N(C)C1=O'
m = Chem.MolFromSmiles(s)
b_mfp = DataStructs.BitVectToBinaryText( AllChem.GetMorganFingerprintAsBitVect(m, 2, nBits=1024) )

curs.execute('set rdkit.tanimoto_threshold=0.95')
curs.execute('select c.id, mol_to_smiles(c.smiles), p.num from compound c, patent p, field_freq f \
             where c.id = f.compound_id and p.id = f.patent_id \
             and c.mfp%%bfp_from_binary_text(%s)', (b_mfp, ))

r = curs.fetchall()

# %%
r[0]
# Out:
# (35625, 'CC[C@]1(c2ccccc2)C(=O)NC(=O)N(C)C1=O', 'US8952008B2')

# %% [markdown]
# Close DB Connection

# %%
curs.close()
conn.close()
